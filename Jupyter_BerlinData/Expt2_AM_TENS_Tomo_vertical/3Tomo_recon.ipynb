# %% [markdown]
# # white-beam interferometry/tomography (March, 2017) Reconstruction with Tomopy/Astra modules

# %% [markdown]
# ### Descriptions: fits folder is needed

# %%
path = '/run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical'
absFitsFileName = 'FITS/'
darkFitsFileName = 'FITS/'
dpcFitsFileName = 'FITS/'
angleIncrement = 360/199.0
par = angleIncrement

# %% [markdown]
# ## Step 1: Initialization

# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
import tomopy
import os
from os import listdir
from os.path import isfile, join
import numpy  
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import string
from numpy.linalg import inv  #matrix calc
import math #log
import scipy
import scipy.ndimage
import scipy.signal #median filter for zero bad pixels
from astropy.io import fits #fits file read and writeTo
import re #sort fits files
from IPython.display import clear_output #clear output

# %% [markdown]
# ## Step 2: Functions

# %% [markdown]
# ### Step 2.1: Read files

# %%
def readFile(path, string):   #search string "white" and "raw"
    allFiles = [f for f in listdir(path) if isfile(join(path,f))]  
    for n in range(0, len(allFiles)):
        allFiles[n] = join(path,allFiles[n])
    allFiles.sort(key=lambda var:[int(x) if x.isdigit() else x for x in re.findall(r'[^0-9]|[0-9]+', var)]) 
    #use "regular expression" to sort filenames
    listfile = [];
    for seq in range (0, len(allFiles)):
        if string in allFiles[seq]:
            listfile.append(allFiles[seq])
    print ('There are '+ str(len(listfile))+ ' '+ string + ' files')        
    return(listfile)

# %% [markdown]
# ## Step 3: path, read files and filenames

# %% [markdown]
# ### set path and filenames

# %%
workdir = path
absFITS = os.path.join(workdir, absFitsFileName)
darkFITS = os.path.join(workdir, darkFitsFileName)
dpcFITS = os.path.join(workdir, dpcFitsFileName)
print ('Your working directory is: ', workdir)
print (absFITS)
# Out:
# Your working directory is:  /run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical
# /run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical/FITS/

# %% [markdown]
# ### read abs fits files and create abs volume

# %%
rotateAngle = -np.arctan(20/1024.0)*180/np.pi

# %%
index = 80 #look at one fit file here
absFitsFiles = readFile(absFITS, "_abs_")
numFiles = len(absFitsFiles)
print (absFitsFiles[index])
oneImage = fits.open(absFitsFiles[index])
oneImage.info()
#oneImage.close()
oneImageArray = oneImage[0].data
oneImageArray.shape
plt.imshow(oneImageArray, 'gray')
plt.show()

img = Image.fromarray(oneImageArray)
img = img.rotate(rotateAngle, resample=Image.BILINEAR, expand = False)
oneImageArray = np.array(img)
plt.imshow(oneImageArray, cmap='gray')
plt.show()

print ('Image dimension is', oneImageArray.shape)
[X, Y] = oneImageArray.shape
print ('X is', X, 'and Y is', Y)
allAbs = np.zeros((numFiles, X, Y)) #create abs volume
print (allAbs.shape)

for index in range(numFiles):
    oneImage = fits.open(absFitsFiles[index])
    oneImageArray = oneImage[0].data
    
     #image rotate
    img = Image.fromarray(oneImageArray)
    img = img.rotate(rotateAngle, resample=Image.BILINEAR, expand = False)
    oneImageArray = np.array(img)
    
    
    allAbs[index, :, :] = oneImageArray
#plt.imshow(allAbs[index, :, :], 'gray')
#plt.show()
allAbs.dtype
# Out:
# There are 200 _abs_ files
# /run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical/FITS/Expt2_AM_TENS_Tomo_vertical_abs_81.0.fits
# Filename: /run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical/FITS/Expt2_AM_TENS_Tomo_vertical_abs_81.0.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       6   (650, 874)   float64
# Image dimension is (874, 650)
# X is 874 and Y is 650
# (200, 874, 650)
# dtype('float64')

# %% [markdown]
# ### read darkfield fits files and create dark volume

# %%
darkFitsFiles = readFile(darkFITS, "_darkfield_")
oneImage = fits.open(darkFitsFiles[index])
oneImage.info()
#oneImage.close()
oneImageArray = oneImage[0].data
oneImageArray.shape
plt.imshow(oneImageArray, 'gray', vmin = 0, vmax=1)
plt.show()
print ('Image dimension is', oneImageArray.shape)
[X, Y] = oneImageArray.shape
print ('X is', X, 'and Y is', Y)
allDark = np.zeros((numFiles, X, Y))
print (allDark.shape)
for index in range(numFiles):
    oneImage = fits.open(darkFitsFiles[index])
    oneImageArray = oneImage[0].data
    
    #image rotate
    img = Image.fromarray(oneImageArray)
    img = img.rotate(rotateAngle, resample=Image.BILINEAR, expand = False)
    oneImageArray = np.array(img)
    
    allDark[index, :, :] = oneImageArray
#plt.imshow(allDark[index, :, :], 'gray',vmin =0, vmax = 1)
#plt.show()
allDark.dtype
allDark = 1 - allDark
# Out:
# There are 200 _darkfield_ files
# Filename: /run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical/FITS/Expt2_AM_TENS_Tomo_vertical_darkfield_200.0.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       6   (650, 874)   float64
# Image dimension is (874, 650)
# X is 874 and Y is 650
# (200, 874, 650)

# %%
np.min(allDark), np.max(allDark)
# Out:
# (-15.53558349609375, 1.0)

# %% [markdown]
# ### read dpc fits files

# %%
dpcFitsFiles = readFile(dpcFITS, "_dpc_")
oneImage = fits.open(dpcFitsFiles[index])
oneImage.info()
#oneImage.close()
oneImageArray = oneImage[0].data
oneImageArray.shape
plt.imshow(oneImageArray, 'gray', vmin = -np.pi, vmax=np.pi)
plt.show()
print ('Image dimension is', oneImageArray.shape)
[X, Y] = oneImageArray.shape
print ('X is', X, 'and Y is', Y)
allDPC = np.zeros((numFiles, X, Y))
print (allDPC.shape)
for index in range(numFiles):
    oneImage = fits.open(dpcFitsFiles[index])
    oneImageArray = oneImage[0].data
    
    #image rotate
    img = Image.fromarray(oneImageArray)
    img = img.rotate(rotateAngle, resample=Image.BILINEAR, expand = False)
    oneImageArray = np.array(img)
    
    
    allDPC[index, :, :] = oneImageArray
#plt.imshow(allDPC[index, :, :], 'gray',vmin =-np.pi, vmax = np.pi)
#plt.show()
allDPC.dtype
# Out:
# There are 200 _dpc_ files
# Filename: /run/media/tomouser/MercurySSD/HZB_Mar2017/Expt2_AM_TENS_Tomo_vertical/FITS/Expt2_AM_TENS_Tomo_vertical_dpc_200.0.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       6   (650, 874)   float64
# Image dimension is (874, 650)
# X is 874 and Y is 650
# (200, 874, 650)
# dtype('float64')

# %% [markdown]
# ### cropping images

# %%
#no needed here
absProj = allAbs
dpcProj = allDPC
darkProj = allDark
absProj.shape
# Out:
# (200, 874, 650)

# %%
plt.imshow(absProj[:, 90, :], cmap='Greys_r')
plt.show()
plt.imshow(absProj[90, :, :], cmap='Greys_r')
plt.show()
#clear_output()

# %%
plt.imshow(dpcProj[:, 90, :], cmap='Greys_r', vmax = np.pi, vmin = -np.pi)
#plt.colorbar()
plt.show()
plt.imshow(dpcProj[90, :, :], cmap='Greys_r', vmax = np.pi, vmin = -np.pi)
#plt.colorbar()
plt.show()
#clear_output()

# %%
plt.imshow(darkProj[80, :, :], cmap='Greys_r', vmin = 0, vmax=1)
#plt.colorbar()
plt.show()
plt.imshow(darkProj[:, 80, :], cmap='Greys_r', vmin = 0, vmax=1)
#plt.colorbar()
plt.show()
print (np.max(darkProj))
print (np.min(darkProj))
#clear_output()
# Out:
# 1.0
# -15.5355834961

# %%
proj = dpcProj
print (np.max(proj))
print (np.min(proj))

listSampleAngles = np.zeros((np.int(360/par+1))) #0 degree to 360 degree
for i in range(len(listSampleAngles)):
    listSampleAngles[i] = i*par/180*np.pi
print ('There are', len(listSampleAngles), 'angles:', '\n\n', listSampleAngles)
numberOfAngles = len(listSampleAngles)
theta = listSampleAngles
#clear_output()
# Out:
# 3.14076638222
# -3.14088106155
# There are 200 angles:
#
#  [ 0.          0.0315738   0.06314759  0.09472139  0.12629518  0.15786898
#   0.18944277  0.22101657  0.25259036  0.28416416  0.31573796  0.34731175
#   0.37888555  0.41045934  0.44203314  0.47360693  0.50518073  0.53675452
#   0.56832832  0.59990211  0.63147591  0.66304971  0.6946235   0.7261973
#   0.75777109  0.78934489  0.82091868  0.85249248  0.88406627  0.91564007
#   0.94721387  0.97878766  1.01036146  1.04193525  1.07350905  1.10508284
#   1.13665664  1.16823043  1.19980423  1.23137803  1.26295182  1.29452562
#   1.32609941  1.35767321  1.389247    1.4208208   1.45239459  1.48396839
#   1.51554218  1.54711598  1.57868978  1.61026357  1.64183737  1.67341116
#   1.70498496  1.73655875  1.76813255  1.79970634  1.83128014  1.86285394
#   1.89442773  1.92600153  1.95757532  1.98914912  2.02072291  2.05229671
#   2.0838705   2.1154443   2.14701809  2.17859189  2.21016569  2.24173948
#   2.27331328  2.30488707  2.33646087  2.36803466  2.39960846  2.43118225
#   2.46275605  2.49432985  2.52590364  2.55747744  2.58905123  2.62062503
#   2.65219882  2.68377262  2.71534641  2.74692021  2.77849401  2.8100678
#   2.8416416   2.87321539  2.90478919  2.93636298  2.96793678  2.99951057
#   3.03108437  3.06265816  3.09423196  3.12580576  3.15737955  3.18895335
#   3.22052714  3.25210094  3.28367473  3.31524853  3.34682232  3.37839612
#   3.40996992  3.44154371  3.47311751  3.5046913   3.5362651   3.56783889
#   3.59941269  3.63098648  3.66256028  3.69413408  3.72570787  3.75728167
#   3.78885546  3.82042926  3.85200305  3.88357685  3.91515064  3.94672444
#   3.97829823  4.00987203  4.04144583  4.07301962  4.10459342  4.13616721
#   4.16774101  4.1993148   4.2308886   4.26246239  4.29403619  4.32560999
#   4.35718378  4.38875758  4.42033137  4.45190517  4.48347896  4.51505276
#   4.54662655  4.57820035  4.60977414  4.64134794  4.67292174  4.70449553
#   4.73606933  4.76764312  4.79921692  4.83079071  4.86236451  4.8939383
#   4.9255121   4.9570859   4.98865969  5.02023349  5.05180728  5.08338108
#   5.11495487  5.14652867  5.17810246  5.20967626  5.24125006  5.27282385
#   5.30439765  5.33597144  5.36754524  5.39911903  5.43069283  5.46226662
#   5.49384042  5.52541421  5.55698801  5.58856181  5.6201356   5.6517094
#   5.68328319  5.71485699  5.74643078  5.77800458  5.80957837  5.84115217
#   5.87272597  5.90429976  5.93587356  5.96744735  5.99902115  6.03059494
#   6.06216874  6.09374253  6.12531633  6.15689013  6.18846392  6.22003772
#   6.25161151  6.28318531]

# %% [markdown]
# ### find rotation center

# %%
rot_center = tomopy.find_center(absProj, theta, init=236, ind=28, tol=0.5)
#proj = tomopy.minus_log(proj)
#remove outlier before recon
print (rot_center)
# Out:
# [ 345.51875]

# %%
#defined by yourself
rot_center = 344

# %% [markdown]
# ## Step 4: TomoPy Reconstruction

# %%
np.min(absProj), np.max(absProj)
# Out:
# (-0.57038825750350952, 1.8834728002548218)

# %%
recon = tomopy.recon(absProj, theta, center=rot_center, algorithm='gridrec')
recon = tomopy.circ_mask(recon, axis=0, ratio=0.85)

# %%
plt.imshow(recon[500, :,:], cmap='Greys_r')
plt.colorbar()
plt.show()
plt.imshow(recon[50, :,:], cmap='Greys_r')
plt.colorbar()
plt.show()

# %%
import h5py
with h5py.File(os.path.join(workdir, 'absRecon_Tomopy_Gridrec.h5'), 'w') as hf:
    hf.create_dataset('slice', data=recon)

# %%
recon = tomopy.recon(darkProj, theta, center=rot_center, algorithm='gridrec')
recon = tomopy.circ_mask(recon, axis=0, ratio=0.85)

# %%
recon.shape
# Out:
# (874, 650, 650)

# %%
plt.imshow(recon[500, :,:], cmap='Greys_r')
plt.colorbar()
plt.show()
plt.imshow(recon[50, :,:], cmap='Greys_r')
plt.colorbar()
plt.show()

# %%
import h5py
with h5py.File(os.path.join(workdir, 'darkRecon_Tomopy_Gridrec.h5'), 'w') as hf:
    hf.create_dataset('slice', data=recon)

# %%
recon = tomopy.recon(dpcProj, theta, center=rot_center, algorithm='gridrec')
recon = tomopy.circ_mask(recon, axis=0, ratio=0.85)

# %%
plt.imshow(recon[350, :,:], cmap='Greys_r')
plt.colorbar()
plt.show()
plt.imshow(recon[200, :,:], cmap='Greys_r')
plt.colorbar()
plt.show()

# %%
#save the reconstructed volume
import h5py
with h5py.File(os.path.join(workdir, 'dpcRecon_Tomopy_Gridrec.h5'), 'w') as hf:
    hf.create_dataset('slice', data=recon)

# %% [markdown]
# ## Step 5: ASTRA Reconstruction

# %% [markdown]
# ### Step 5.1 sirt for dpc

# %%
#tomopy.astra?
extra_options ={'MinConstraint':-np.pi}
options = {'proj_type':'cuda', 'method':'SIRT_CUDA', 'num_iter':40,'extra_options':extra_options}
dpcRecon = tomopy.recon(dpcProj, theta, center=rot_center, algorithm=tomopy.astra, options=options)
dpcRecon = tomopy.circ_mask(dpcRecon, axis=0, ratio=0.85)
plt.imshow(dpcRecon[80, :,:], cmap='Greys_r', vmin = np.min(dpcRecon)/2, vmax = np.max(dpcRecon)/2)
plt.colorbar()
plt.show()

# %%
import h5py
with h5py.File(os.path.join(workdir, 'dpcRecon_Astra_SIRT_CUDA_iter40.h5'), 'w') as hf:
    hf.create_dataset('slice', data=dpcRecon)

# %% [markdown]
# ### sirt for dark-field

# %%
#tomopy.astra?
extra_options ={'MinConstraint':-0.5}
options = {'proj_type':'cuda', 'method':'SIRT_CUDA', 'num_iter':40,'extra_options':extra_options}
darkRecon = tomopy.recon(darkProj, theta, center=rot_center, algorithm=tomopy.astra, options=options)
darkRecon = tomopy.circ_mask(darkRecon, axis=0, ratio=0.85)

# %%
plt.imshow(darkRecon[800, :,:], cmap='Greys_r', vmin = np.min(darkRecon), vmax = np.max(darkRecon))
plt.colorbar()
plt.show()

# %%
import h5py
with h5py.File(os.path.join(workdir, 'darkRecon_Astra_SIRT_CUDA_iter40.h5'), 'w') as hf:
    hf.create_dataset('slice', data=darkRecon)

# %% [markdown]
# ### sirt for absorption

# %%
#tomopy.astra?
extra_options ={'MinConstraint':-0.1}
options = {'proj_type':'cuda', 'method':'SIRT_CUDA', 'num_iter':40,'extra_options':extra_options}
absRecon = tomopy.recon(absProj, theta, center=rot_center, algorithm=tomopy.astra, options=options)
absRecon = tomopy.circ_mask(absRecon, axis=0, ratio=0.85)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-75416fbbd1a7> in <module>()
#       2 extra_options ={'MinConstraint':-0.1}
#       3 options = {'proj_type':'cuda', 'method':'SIRT_CUDA', 'num_iter':40,'extra_options':extra_options}
# ----> 4 absRecon = tomopy.recon(absProj, theta, center=rot_center, algorithm=tomopy.astra, options=options)
#       5 absRecon = tomopy.circ_mask(absRecon, axis=0, ratio=0.85)
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/recon/algorithm.pyc in recon(tomo, theta, center, sinogram_order, algorithm, init_recon, ncore, nchunk, **kwargs)
#     282     recon = _init_recon(recon_shape, init_recon)
#     283     return _dist_recon(
# --> 284         tomo, center_arr, recon, _get_func(algorithm), args, kwargs, ncore, nchunk)
#     285
#     286
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/recon/algorithm.pyc in _dist_recon(tomo, center, recon, algorithm, args, kwargs, ncore, nchunk)
#     351         axis=0,
#     352         ncore=ncore,
# --> 353         nchunk=nchunk)
#     354
#     355
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/util/mproc.pyc in distribute_jobs(arr, func, axis, args, kwargs, ncore, nchunk, out)
#     220             raise
#     221
# --> 222         clear_queue(queue, shared_arrays, shared_out)
#     223     else:
#     224         for m in map_args:
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/util/mproc.pyc in clear_queue(queue, shared_arrays, shared_out)
#     276     while not queue.empty():
#     277         params = queue.get(False)
# --> 278         _arg_parser(params)
#     279
#     280
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/util/mproc.pyc in _arg_parser(params)
#     259     # NOTE: will only copy if actually different arrays
#     260     try:
# --> 261         result = func(*func_args, **kwargs)
#     262         if result is not None and isinstance(result, np.ndarray):
#     263             outslice = slice_axis(SHARED_OUT, slc, axis)
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/recon/wrappers.pyc in astra(*args, **kwargs)
#     120         raise mproc.RunOnHostException()
#     121     else:
# --> 122         astra_run(*args, **kwargs)
#     123
#     124
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/tomopy/recon/wrappers.pyc in astra_run(tomo, center, recon, theta, **kwargs)
#     230             algs.append(alg_id)
#     231         if nbatch==1:
# --> 232             astra_mod.algorithm.run(algs[0], niter)
#     233         else:
#     234             thrds = [executor.submit(lambda q: astra_mod.algorithm_c.run(q, niter), alg_id) for alg_id in algs]
#
# /home/tomouser/anaconda2/envs/APS/lib/python2.7/site-packages/astra/algorithm.pyc in run(i, iterations)
#      46
#      47     """
# ---> 48     return a.run(i,iterations)
#      49
#      50 def get_res_norm(i):
#
# KeyboardInterrupt:

# %%
plt.imshow(absRecon[800, :,:], cmap='Greys_r', vmin = np.min(absRecon), vmax = np.max(absRecon))
plt.colorbar()
plt.show()
plt.imshow(absRecon[0, :,:], cmap='Greys_r', vmin = np.min(absRecon), vmax = np.max(absRecon))
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-8f9d885d41d2> in <module>()
# ----> 1 plt.imshow(absRecon[800, :,:], cmap='Greys_r', vmin = np.min(absRecon), vmax = np.max(absRecon))
#       2 plt.colorbar()
#       3 plt.show()
#       4 plt.imshow(absRecon[0, :,:], cmap='Greys_r', vmin = np.min(absRecon), vmax = np.max(absRecon))
#       5 plt.colorbar()
#
# NameError: name 'absRecon' is not defined

# %%
import h5py
with h5py.File(os.path.join(workdir, 'absRecon_Astra_SIRT_CUDA_iter40.h5'), 'w') as hf:
    hf.create_dataset('slice', data=absRecon)
